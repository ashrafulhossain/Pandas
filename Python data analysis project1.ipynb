# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Ashraful\Downloads\pndas_project.csv")

# %%
data
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012    -1.8              -3.9         86                4
# 1       1/1/2012    -1.8              -3.7         87                4
# 2       1/1/2012    -1.8              -3.4         89                7
# 3       1/1/2012    -1.5              -3.2         88                6
# 4       1/1/2012    -1.5              -3.3         88                7
# ...          ...     ...               ...        ...              ...
# 8779  12/31/2012     0.1              -2.7         81               30
# 8780  12/31/2012     0.2              -2.4         83               24
# 8781  12/31/2012    -0.5              -1.5         93               28
# 8782  12/31/2012    -0.2              -1.8         89               28
# 8783  12/31/2012     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa               Weather
# 0               8.0     101.24                   Fog
# ...

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.nunique()
# Out:
# Date/Time           366
# Temp_C              533
# Dew Point Temp_C    489
# Rel Hum_%            83
# Wind Speed_km/h      34
# Visibility_km        24
# Press_kPa           518
# Weather              50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
#  # Q) 1. Find all the unique "Wind Speed" values in the data.

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.nunique()
# Out:
# Date/Time           366
# Temp_C              533
# Dew Point Temp_C    489
# Rel Hum_%            83
# Wind Speed_km/h      34
# Visibility_km        24
# Press_kPa           518
# Weather              50
# dtype: int64

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# # Q) 2. Find the number of times when the 'Weather exactly is Clear'

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data[data['Weather']== 'Clear']
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012   -16.9             -24.8         50               24
# 114     1/5/2012    -7.1             -14.4         56               11
# 115     1/5/2012    -9.2             -15.4         61                7
# 116     1/5/2012    -9.8             -15.7         62                9
# 117     1/5/2012    -9.0             -14.8         63               13
# ...          ...     ...               ...        ...              ...
# 8646  12/26/2012   -13.4             -14.8         89                4
# 8698  12/28/2012    -6.1              -8.6         82               19
# 8713  12/29/2012   -11.9             -13.6         87               11
# 8714  12/29/2012   -11.8             -13.1         90               13
# 8756  12/30/2012   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# 67             25.0     101.74   Clear
# ...

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012   -16.9             -24.8         50               24
# 114     1/5/2012    -7.1             -14.4         56               11
# 115     1/5/2012    -9.2             -15.4         61                7
# 116     1/5/2012    -9.8             -15.7         62                9
# 117     1/5/2012    -9.0             -14.8         63               13
# ...          ...     ...               ...        ...              ...
# 8646  12/26/2012   -13.4             -14.8         89                4
# 8698  12/28/2012    -6.1              -8.6         82               19
# 8713  12/29/2012   -11.9             -13.6         87               11
# 8714  12/29/2012   -11.8             -13.1         90               13
# 8756  12/30/2012   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# 67             25.0     101.74   Clear
# ...

# %% [markdown]
# # Q) 3.Find the number of times when the 'Wind Speed was exactly 4 km/h'

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012    -1.8              -3.9         86                4
# 1       1/1/2012    -1.8              -3.7         87                4
# 96      1/5/2012    -8.8             -11.7         79                4
# 101     1/5/2012    -7.0              -9.5         82                4
# 146     1/7/2012    -8.1             -11.1         79                4
# ...          ...     ...               ...        ...              ...
# 8768  12/31/2012    -8.6             -10.3         87                4
# 8769  12/31/2012    -8.1              -9.6         89                4
# 8770  12/31/2012    -7.4              -8.9         89                4
# 8772  12/31/2012    -5.8              -7.5         88                4
# 8773  12/31/2012    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# 0               8.0     101.24           Fog
# ...

# %% [markdown]
# # Q) 4. Find out the all null values in the data

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# # Q) 5. Rename the column name 'Weather of the data frame to Weather Condition'

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.rename(columns = {'Weather': 'Weather Condition'}, inplace = True)

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# # Q) 6. What is the mean 'visibility'?

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # Q) 7. What is the Standard Deviation of 'Pressure' in this data?

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # Q) 8. What is the variance of 'Relative Humidity' in this data?

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# # Q) 9. Find all instances when 'Snow' was recorded

# %%
data.head()
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
# 2  1/1/2012    -1.8              -3.4         89                7
# 3  1/1/2012    -1.5              -3.2         88                6
# 4  1/1/2012    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data[data['Weather Condition'] == 'Snow']
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55      1/3/2012   -14.0             -19.5         63               19
# 84      1/4/2012   -13.7             -21.7         51               11
# 86      1/4/2012   -11.3             -19.0         53                7
# 87      1/4/2012   -10.2             -16.3         61               11
# 88      1/4/2012    -9.4             -15.5         61               13
# ...          ...     ...               ...        ...              ...
# 8779  12/31/2012     0.1              -2.7         81               30
# 8780  12/31/2012     0.2              -2.4         83               24
# 8781  12/31/2012    -0.5              -1.5         93               28
# 8782  12/31/2012    -0.2              -1.8         89               28
# 8783  12/31/2012     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Condition
# 55             25.0     100.95              Snow
# ...

# %%
data[data['Weather Condition'].str.contains('Snow')].tail(50)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012    -4.5              -6.2         88               37
# 8681  12/27/2012    -4.2              -5.9         88               32
# 8682  12/27/2012    -4.0              -5.7         88               28
# 8683  12/27/2012    -3.9              -5.6         88               26
# 8684  12/27/2012    -3.7              -5.3         89               37
# 8685  12/27/2012    -3.7              -4.8         92               24
# 8686  12/27/2012    -3.8              -4.6         94               20
# 8687  12/27/2012    -4.0              -5.6         89               24
# 8688  12/28/2012    -4.2              -5.7         89               19
# 8689  12/28/2012    -4.4              -6.6         85               15
# 8690  12/28/2012    -4.3              -6.3         86               11
# 8691  12/28/2012    -4.6              -5.9         91               13
# ...

# %% [markdown]
# # Q) 10. Find all instances when "Wind is speed above 24" and Visibility is 25'.

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
 data[(data['Wind Speed_km/h'] < 24) & (data['Visibility_km'] == 25)]
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 20      1/1/2012     3.2               1.3         87               19
# 21      1/1/2012     4.0               1.7         85               20
# 41      1/2/2012    -2.1              -9.5         57               22
# 46      1/2/2012    -7.0             -14.7         54               20
# 49      1/3/2012    -9.7             -17.2         54               20
# ...          ...     ...               ...        ...              ...
# 8762  12/31/2012   -10.1             -13.4         77                9
# 8763  12/31/2012   -11.8             -14.4         81                6
# 8764  12/31/2012   -10.5             -12.8         83               11
# 8765  12/31/2012   -10.2             -12.4         84                6
# 8766  12/31/2012    -9.7             -11.7         85                4
#
#       Visibility_km  Press_kPa Weather Condition
# 20             25.0      99.50            Cloudy
# ...

# %% [markdown]
# # Q) 11. What is the Mean value each of column against each 'Weather condition'

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# # Q) 12. What is the Maximum and Minimum value of each column aginst each 'Weather Condition'?

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data.groupby('Weather Condition').min().head(5)
# Out:
#                           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                     1/11/2012   -23.3             -28.5         20
# Cloudy                     1/1/2012   -21.4             -26.8         18
# Drizzle                   1/23/2012     1.1              -0.2         74
# Drizzle,Fog               1/23/2012     0.0              -1.6         85
# Drizzle,Ice Pellets,Fog  12/17/2012     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                                  0           11.3      99.52
# Cloudy                                 0           11.3      98.39
# Drizzle                                0            6.4      97.84
# Drizzle,Fog                            0            1.0      98.65
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
data.groupby('Weather Condition').max().head(5)
# Out:
#                           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                      9/9/2012    32.8              20.4         99
# Cloudy                     9/9/2012    30.5              22.6         99
# Drizzle                   9/30/2012    18.8              17.7         96
# Drizzle,Fog               9/30/2012    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                                 33           48.3     103.63
# Cloudy                                54           48.3     103.65
# Drizzle                               30           25.0     101.56
# Drizzle,Fog                           28            9.7     102.07
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %% [markdown]
# # Q) 13. Show all the Records where Weather Condition is Fog

# %%
data[data['Weather Condition']== 'Fog']
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012    -1.8              -3.9         86                4
# 1       1/1/2012    -1.8              -3.7         87                4
# 4       1/1/2012    -1.5              -3.3         88                7
# 5       1/1/2012    -1.4              -3.3         87                9
# 6       1/1/2012    -1.5              -3.1         89                7
# ...          ...     ...               ...        ...              ...
# 8716  12/29/2012   -16.0             -17.2         90                6
# 8717  12/29/2012   -14.8             -15.9         91                4
# 8718  12/29/2012   -13.8             -15.3         88                4
# 8719  12/29/2012   -14.8             -16.4         88                7
# 8722  12/29/2012   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather Condition
# 0               8.0     101.24               Fog
# ...

# %% [markdown]
# # Q) 14. Find all instances when 'Weather is Clear or Visibility is above 40'.

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012   -16.9             -24.8         50               24
# 106     1/5/2012    -6.0             -10.0         73               17
# 107     1/5/2012    -5.6             -10.2         70               22
# 108     1/5/2012    -4.7              -9.6         69               20
# 109     1/5/2012    -4.4              -9.7         66               26
# ...          ...     ...               ...        ...              ...
# 8749  12/30/2012   -12.4             -16.2         73               37
# 8750  12/30/2012   -11.8             -16.1         70               37
# 8751  12/30/2012   -11.3             -15.6         70               32
# 8752  12/30/2012   -11.4             -15.5         72               26
# 8756  12/30/2012   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather Condition
# 67             25.0     101.74             Clear
# ...

# %% [markdown]
# # Q) 15. Find all instance When:
#    ###  A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
#    ### or
#    ### 'Visibility is above 40'

# %%
data.head(2)
# Out:
#   Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012    -1.8              -3.9         86                4
# 1  1/1/2012    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Weather Condition'] == 'Clear') & (data['Rel Hum_%'] > 50) | (data['Visibility_km'] > 40)]
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012    -6.0             -10.0         73               17
# 107     1/5/2012    -5.6             -10.2         70               22
# 108     1/5/2012    -4.7              -9.6         69               20
# 109     1/5/2012    -4.4              -9.7         66               26
# 110     1/5/2012    -5.1             -10.7         65               22
# ...          ...     ...               ...        ...              ...
# 8749  12/30/2012   -12.4             -16.2         73               37
# 8750  12/30/2012   -11.8             -16.1         70               37
# 8751  12/30/2012   -11.3             -15.6         70               32
# 8752  12/30/2012   -11.4             -15.5         72               26
# 8756  12/30/2012   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather Condition
# 106            48.3     100.45      Mainly Clear
# ...
